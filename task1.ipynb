# %%
print('this is task 11')

# %%
dbutils.widgets.text('name','A')
a = dbutils.widgets.get('name')
print('Hi Mr',a)
print(type(a))

# %%
dbutils.widgets.text('date','2026-01-12')
date = dbutils.widgets.get('date')
print(date)
print(type(date))
from datetime import datetime

date_obj = datetime.strptime(date, "%Y-%m-%d").date()

print(date_obj)
print(type(date_obj))

# %%
dbutils.jobs.taskValues.set('name',a)
